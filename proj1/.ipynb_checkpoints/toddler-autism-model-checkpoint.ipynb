# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#data = pd.read_csv("C:\\data\\DataScience\\DataSets\\Autism-Screening\\Toddler Autism dataset.csv")
data = pd.read_csv("Toddler Autism dataset.csv")
#data.columns=['A1','A2','.............']
#print(data.info())
data['JaundiceCode']= data.Jaundice.eq('yes').mul(1)
#data['ASDCode']= data.ASD.eq('yes').mul(1)
print(data.head())
print(data.shape)
print(data.tail())
# Out:
#    Case_No  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0        1         0         0         0         0         0         0
# 1        2         1         1         0         0         0         1
# 2        3         1         0         0         0         0         0
# 3        4         1         1         1         1         1         1
# 4        5         1         1         0         1         1         1
#
#    A7_Score  A8_Score  A9_Score  A10_Score  Age_Mons  Qchat-10-Score Sex  \
# 0         1         1         0          1        28               3   f
# 1         1         0         0          0        36               4   m
# 2         1         1         0          1        36               4   m
# 3         1         1         1          1        24              10   m
# 4         1         1         1          1        20               9   f
#
#         Ethnicity Jaundice Family_mem_with_ASD Who completed the test  ASD  \
# ...

# %%
pd.crosstab(data.ASD, data.JaundiceCode).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("Jaundice")
plt.show()

# %%
pd.crosstab(data.ASD, data.A1_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A1 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A2_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A2 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A3_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A3 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A4_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A4 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A5_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A5 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A6_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A6 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A7_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A7 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A8_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A8 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A9_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A9 Score")
plt.show()

# %%
pd.crosstab(data.ASD, data.A10_Score).plot(kind='bar')
plt.xlabel("ASD")
plt.ylabel("A10 Score")
plt.show()

# %%
corr = data.corr()
plt.figure(figsize = (20,20))
sns.heatmap(data = corr, annot = True, square = True, cbar = True)
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.countplot(x = 'Ethnicity', data = data)
plt.show()

# %%
sns.countplot(x = 'Jaundice', hue = 'Sex', data = data)
plt.show()
